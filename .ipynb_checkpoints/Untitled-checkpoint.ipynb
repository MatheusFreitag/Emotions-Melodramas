# %%
import pandas as pd
import re
from nltk.corpus import stopwords
import os

# %%
df_Carly = pd.DataFrame(columns=['Álbum', 'Ano', 'Música', 'Corpus'])

# %%
path = './data/Carly Rae Jepsen/Dedicated_2019'
for name_of_the_file in os.listdir(path):
    print(name_of_the_file)
    with open(str(path) + '/' + name_of_the_file) as f:
        file = f.read()
        file = re.sub(r'\[.*\]', "", file)
        file = list(filter(None, file.split('\n')))
        
        location = df_Carly.shape[0]
        df_Carly.loc[location, 'Álbum'] = 'Dedicated'
        df_Carly.loc[location, 'Ano'] = '2019'
        df_Carly.loc[location, 'Música'] = name_of_the_file[:-4]
        df_Carly.loc[location, 'Corpus'] = " ".join(file)
# Out:
# No Drug Like Me.txt
# Everything He Needs.txt
# Feels Right.txt
# Party for one.txt
# Right Words Wrong Time.txt
# Too Much.txt
# Want You In My Room.txt
# Now That I Found You.txt
# I'll be your girl.txt
# Automatically In Love.txt
# Real Love.txt
# Happy Not Knowing.txt
# The Sound.txt
# Julien.txt
# For sure.txt

# %%
path = './data/Carly Rae Jepsen/Emotion_2015/'
for name_of_the_file in os.listdir(path):
    print(name_of_the_file)
    with open(str(path) + '/' + name_of_the_file) as f:
        file = f.read()
        file = re.sub(r'\[.*\]', "", file)
        file = list(filter(None, file.split('\n')))
        
        location = df_Carly.shape[0]
        df_Carly.loc[location, 'Álbum'] = 'Emotion'
        df_Carly.loc[location, 'Ano'] = '2015'
        df_Carly.loc[location, 'Música'] = name_of_the_file[:-4]
        df_Carly.loc[location, 'Corpus'] = " ".join(file)
# Out:
# All That.txt
# I Didn’t Just Come Here to Dance.txt
# LA Hallucinations.txt
# Your Type.txt
# Run Away With Me.txt
# When I Needed You.txt
# Warm Blood.txt
# Making The Most Of The Night.txt
# Boy Problems.txt
# Black Heart.txt
# Favourite Colour.txt
# Love Again.txt
# I Really Like You.txt
# Emotion.txt
# Gimmie Love.txt
# Let’s Get Lost.txt

# %%
df_Carly
# Out:
#         Álbum   Ano                            Música  \
# 0   Dedicated  2019                   No Drug Like Me
# 1   Dedicated  2019               Everything He Needs
# 2   Dedicated  2019                       Feels Right
# 3   Dedicated  2019                     Party for one
# 4   Dedicated  2019            Right Words Wrong Time
# 5   Dedicated  2019                          Too Much
# 6   Dedicated  2019               Want You In My Room
# 7   Dedicated  2019              Now That I Found You
# 8   Dedicated  2019                 I'll be your girl
# 9   Dedicated  2019             Automatically In Love
# 10  Dedicated  2019                         Real Love
# 11  Dedicated  2019                 Happy Not Knowing
# 12  Dedicated  2019                         The Sound
# 13  Dedicated  2019                            Julien
# 14  Dedicated  2019                          For sure
# 15    Emotion  2015                          All That
# ...

# %%
df_Carly.to_csv('Carly Rae Jepsen.tsv', sep='\t')

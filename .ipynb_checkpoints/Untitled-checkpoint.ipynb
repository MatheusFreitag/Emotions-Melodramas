# %%
import pandas as pd
import re
from nltk.corpus import stopwords
import os

# %%
stopwords.words('english')
# Out:
# (179, 179)

# %%
df = pd.read_csv('data/Lorde.tsv', sep='\t')
del df['Unnamed: 0']

# %%
df.loc[df['Álbum'] == 'Pure Heroine (Extended)', 'Ano'] = 2013

# %%
def remove_stopwords(text):
    text = text.split(' ')
    text = [x for x in text if x not in stopwords.words('english')]
    return ' '.join(text)

# %%
df.loc[:, 'Corpus'] = df.loc[:, 'Corpus'].apply(lambda x: remove_stopwords(x))

# %%
def remove_ponctuation(text):
    return  " ".join(re.findall("[a-zA-Z]+", text))

# %%
df.loc[:, 'Corpus'] = df.loc[:, 'Corpus'].apply(lambda x: remove_ponctuation(x))

# %%
def remove_words_with_less_3(text):
    text = text.split(' ')
    text = [x for x in text if len(x)>3]
    return ' '.join(text)

# %%
df.loc[:, 'Corpus'] = df.loc[:, 'Corpus'].apply(lambda x: remove_words_with_less_3(x))

# %%
df.loc[:, 'Corpus'] = df.loc[:, 'Corpus'].apply(lambda x: x.lower())

# %%
df
# Out:
#                       Álbum   Ano                  Música  \
# 0                 Melodrama  2017     Liability (Reprise)
# 1                 Melodrama  2017    Sober II (Melodrama)
# 2                 Melodrama  2017  Hard Feelings-Loveless
# 3                 Melodrama  2017                   Sober
# 4                 Melodrama  2017                Supercut
# 5                 Melodrama  2017              The Louvre
# 6                 Melodrama  2017      Writer in the Dark
# 7                 Melodrama  2017       Homemade Dynamite
# 8                 Melodrama  2017               Liability
# 9                 Melodrama  2017          Perfect Places
# 10                Melodrama  2017             Green Light
# 11  Pure Heroine (Extended)  2013                    Ribs
# 12  Pure Heroine (Extended)  2013       White Teeth Teens
# 13  Pure Heroine (Extended)  2013                 Bravado
# 14  Pure Heroine (Extended)  2013           A World Alone
# 15  Pure Heroine (Extended)  2013                  Royals
# 16  Pure Heroine (Extended)  2013               No Better
# 17  Pure Heroine (Extended)  2013             Biting Down
# 18  Pure Heroine (Extended)  2013    Million Dollar Bills
# 19  Pure Heroine (Extended)  2013              Still Sane
# 20  Pure Heroine (Extended)  2013          Glory and Gore
# 21  Pure Heroine (Extended)  2013           The Love Club
# 22  Pure Heroine (Extended)  2013          Buzzcut Season
# 23  Pure Heroine (Extended)  2013                 400 Lux
# 24  Pure Heroine (Extended)  2013          Swinging Party
# 25  Pure Heroine (Extended)  2013            Tennis Court
# 26  Pure Heroine (Extended)  2013                    Team
#
#                                                Corpus
# 0   liability liability much little much whatcha g...
# 1   asked feeling psycho high know remember mornin...
# 2   back tell please could tender close give minut...
# 3   night midnight lose mind night midnight lose m...
# 4   head play supercut magic gave love lost head v...
# 5   well summer slipped underneath tongue days nig...
# 6   break news walking good someone else sorry nev...
# 7   couple rebel pilots flying nowhere know super ...
# 8   baby really hurt crying taxi wanna know says m...
# 9   every night live feel party bones watch waster...
# 10  makeup somebody else order different drinks ba...
# 11  drink spilt lover spit left repeat stay home d...
# 12  seen dead guess lucky dark like stay impress e...
# 13  life fighting talk friends heart jumps around ...
# 14  that slow burn wait gets dark bruising feel gr...
# 15  never seen diamond flesh teeth wedding rings m...
# 16  roll every summer there strength numbers breat...
# 17  feels better biting feels better biting feels ...
# 18  there nothing want money time million dollar b...
# 19  today birthday riding high hair dripping hidin...
# 20  there humming restless summer slipping course ...
# 21  clique want punched days enough card games eas...
# 22  remember head caught flame kissed scalp caress...
# 23  never done killing time kill till veins blue c...
# 24  bring lampshade somewhere there party here nev...
# 25  think boring people talk making smart words ag...
# 26  wait till announced lost graces hounds stay ch...
